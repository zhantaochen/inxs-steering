# %%
# %load_ext autoreload
# %autoreload 2
from inxss.utils_spectrum import calc_Sqw_from_Syy_Szz
from inxss.experiment import SimulatedExperiment

import torch
import numpy as np
from scipy.interpolate import RegularGridInterpolator

from inxss import SpectrumDataset, SpecNeuralRepr, Particle, PsiMask, OnlineVariance, linspace_2D_equidistant
from inxss.utils_visualization import arc_arrow, rad_arrow

import matplotlib.pyplot as plt

from tqdm import tqdm 

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
# device = 'cpu'

torch.set_default_dtype(torch.float32)

# %%
from inxss.experiment import NeutronExperiment, SimulatedExperiment

# %%
model_path = '/pscratch/sd/z/zhantao/inxs_steering_production/models/version_14896845/checkpoints/epoch=7160-step=343728.ckpt'
data = torch.load('/pscratch/sd/z/zhantao/inxs_steering_production/experiment_data/summarized_neutron_data_w_bkg_260meV.pt')
print(data.keys())
# Out:
# dict_keys(['grid', 'S', 'background', 'background_dict'])

# %% [markdown]
# ### setup experiment simulator

# %%
from inxss.experiment import Background

# %%
background = Background(
    tuple([data['grid'][_grid] for _grid in ['h_grid', 'k_grid', 'l_grid']]), 
    data['grid']['w_grid'], 
    data['background']
)

# %% [markdown]
# ### Testing integrated steer module

# %%
from inxss.steer_neutron import NeutronExperimentSteerer

# %%
# global_mask = (data['S']>0).bool()

# global_mask = torch.ones_like(data['S']).bool()
global_mask = 1.

# %%
particle_filter_config = {
    "num_particles": 1000,
    "dim_particles": 2,
    "prior_configs": {'types': ['uniform', 'uniform'], 'args': [{'low': 20, 'high': 40}, {'low': -5, 'high': 5}]}
}


grid_info = {
    'h_grid': [-4.0, 4.0, 121],
    'k_grid': [-4.0, 4.0, 121],
    'l_grid': [-10.0, 10.0, 31],
    'w_grid': [20.0, 200.0, 51]
}
# grid_info = {
#     _: [eval(f'neutron_exp.{_}').min().item(), eval(f'neutron_exp.{_}').max().item(), eval(f'neutron_exp.{_}').shape[0]] 
#     for _ in ['h_grid', 'k_grid', 'l_grid', 'w_grid']}

mask_config = {
    "raw_mask_path": '/pscratch/sd/z/zhantao/inxs_steering/La2NiO4_bool',
    "memmap_mask_path": '/pscratch/sd/z/zhantao/inxs_steering/mask_data',
    "grid_info": grid_info,
    "preload": False,
    "build_from_scratch_if_no_memmap": True,
    "global_mask": None
}

# %%
psi_mask = PsiMask(**mask_config)
# Out:
# obtained memmap mask name as: mask_h_-4.0_4.0_121_k_-4.0_4.0_121_l_-10.0_10.0_31_w_20.0_200.0_51.npy
# mask memmap not found, building from scratch (typically ~10 mins)...
# 100%|██████████| 360/360 [08:04<00:00,  1.34s/it]
# saved memmap mask to: /pscratch/sd/z/zhantao/inxs_steering/mask_data/mask_h_-4.0_4.0_121_k_-4.0_4.0_121_l_-10.0_10.0_31_w_20.0_200.0_51.npy

# %%
for ii, i in enumerate(test_idx):
    print(ii, spinw_data['params'][i])
# Out:
# 0 tensor([26.4065, -3.4445], dtype=torch.float64)
# 1 tensor([22.4046,  3.4776], dtype=torch.float64)
# 2 tensor([20.3975, -1.9879], dtype=torch.float64)
# 3 tensor([30.6803,  3.0629], dtype=torch.float64)
# 4 tensor([38.2439,  0.8350], dtype=torch.float64)
# 5 tensor([20.9757,  1.5469], dtype=torch.float64)
# 6 tensor([30.9052, -2.5636], dtype=torch.float64)
# 7 tensor([21.5248, -2.7835], dtype=torch.float64)
# 8 tensor([31.3150, -0.7569], dtype=torch.float64)
# 9 tensor([35.3057, -1.8538], dtype=torch.float64)
# 10 tensor([26.8561, -2.1235], dtype=torch.float64)
# 11 tensor([22.0734,  0.1368], dtype=torch.float64)
# 12 tensor([21.0442, -3.3076], dtype=torch.float64)
# 13 tensor([30.2704, -2.8482], dtype=torch.float64)
# 14 tensor([35.0231,  0.1786], dtype=torch.float64)
# 15 tensor([37.1222, -2.8539], dtype=torch.float64)
# 16 tensor([31.0048, -2.2552], dtype=torch.float64)
# 17 tensor([24.1704,  3.0938], dtype=torch.float64)
# 18 tensor([38.9347, -2.0850], dtype=torch.float64)
# 19 tensor([24.5072,  1.1760], dtype=torch.float64)
# 20 tensor([35.9548, -0.7575], dtype=torch.float64)
# 21 tensor([26.8353,  4.5058], dtype=torch.float64)
# 22 tensor([21.2072, -2.6648], dtype=torch.float64)
# 23 tensor([36.6954, -1.1677], dtype=torch.float64)
# 24 tensor([22.5425, -3.9206], dtype=torch.float64)
# 25 tensor([26.9962, -4.9002], dtype=torch.float64)
# 26 tensor([27.3359,  3.8633], dtype=torch.float64)
# 27 tensor([21.9818, -3.1161], dtype=torch.float64)
# 28 tensor([29.6744,  0.7089], dtype=torch.float64)
# 29 tensor([35.3467,  0.4152], dtype=torch.float64)
# 30 tensor([38.2631, -1.4592], dtype=torch.float64)
# 31 tensor([35.8801, -2.8698], dtype=torch.float64)
# 32 tensor([35.8515,  4.4433], dtype=torch.float64)
# 33 tensor([28.4506, -2.6662], dtype=torch.float64)
# 34 tensor([37.3703, -2.2103], dtype=torch.float64)
# 35 tensor([39.7592,  1.1553], dtype=torch.float64)
# 36 tensor([20.0944, -2.9209], dtype=torch.float64)
# 37 tensor([31.9026,  2.5978], dtype=torch.float64)
# 38 tensor([27.8224, -4.8409], dtype=torch.float64)
# 39 tensor([31.7040,  0.1666], dtype=torch.float64)
# 40 tensor([20.0558, -3.2937], dtype=torch.float64)
# 41 tensor([21.4191,  3.0861], dtype=torch.float64)
# 42 tensor([28.4112, -3.2130], dtype=torch.float64)
# 43 tensor([30.7285,  4.2574], dtype=torch.float64)
# 44 tensor([26.5707, -2.8724], dtype=torch.float64)
# 45 tensor([23.7322, -0.3530], dtype=torch.float64)
# 46 tensor([29.9086,  3.3918], dtype=torch.float64)
# 47 tensor([27.2789, -0.2777], dtype=torch.float64)
# 48 tensor([29.0650,  1.4566], dtype=torch.float64)
# 49 tensor([24.7520, -3.7173], dtype=torch.float64)
# 50 tensor([26.5882, -3.3365], dtype=torch.float64)
# 51 tensor([28.8555,  0.7225], dtype=torch.float64)
# 52 tensor([20.6338,  2.1271], dtype=torch.float64)
# 53 tensor([29.2521, -1.0264], dtype=torch.float64)
# 54 tensor([29.8660,  2.2482], dtype=torch.float64)
# 55 tensor([39.4876, -4.8724], dtype=torch.float64)
# 56 tensor([27.7757,  1.3957], dtype=torch.float64)
# 57 tensor([28.2206, -0.5710], dtype=torch.float64)
# 58 tensor([27.9140, -0.6762], dtype=torch.float64)
# 59 tensor([27.6199, -4.6073], dtype=torch.float64)

# %%
from inxss.experiment import SimulatedExperiment
from sklearn.model_selection import train_test_split
idx_plot = 32

spinw_data = torch.load('/pscratch/sd/z/zhantao/inxs_steering/SpinW_data/summarized_AFM_data_2023Sep13.pt')

# spec_dataset = SpectrumDataset(
#     '/pscratch/sd/z/zhantao/inxs_steering/SpinW_data/summarized_AFM_data_2023Sep13.pt',
#     num_wq=50
# )

train_idx, val_test_idx = train_test_split(np.arange(spinw_data['Syy'].shape[0]), test_size=0.2, random_state=42)
val_idx, test_idx = train_test_split(val_test_idx, test_size=0.5, random_state=42)

print(spinw_data['params'][test_idx[idx_plot]])
# Out:
# tensor([35.8515,  4.4433], dtype=torch.float64)

# %%
sim_experiment = SimulatedExperiment(
    spinw_data['q_grid'], spinw_data['w_grid'], 
    spinw_data['Syy'][test_idx[idx_plot]], spinw_data['Szz'][test_idx[idx_plot]],
    neutron_flux=1000
)

# %%
sim_experiment.prepare_experiment(psi_mask.hklw_grid)
# sim_experiment.Sqw = sim_experiment.Sqw / sim_experiment.Sqw.sum() * (data['S'] - torch.from_numpy(data['background'])).sum()

# %%
sim_experiment.Sqw.max()
# Out:
# tensor(86.0547, dtype=torch.float64)

# %%
# experiment_config = {
#     "q_grid": tuple([data['grid'][_grid] for _grid in ['h_grid', 'k_grid', 'l_grid']]),
#     "w_grid": data['grid']['w_grid'],
#     "S_grid": torch.from_numpy(data['background']) + \
#         global_mask * 10. * sim_experiment.Sqw,
#     "S_scale_factor": 1.
# }

# background_config = {
#     "q_grid": tuple([data['grid'][_grid] for _grid in ['h_grid', 'k_grid', 'l_grid']]),
#     "w_grid": data['grid']['w_grid'],
#     "bkg_grid": data['background']
# }

experiment_config = {
    "q_grid": tuple([torch.linspace(*grid_info[_grid]) for _grid in ['h_grid', 'k_grid', 'l_grid']]),
    "w_grid": torch.linspace(*grid_info['w_grid']),
    "S_grid": 10 * (global_mask * sim_experiment.Sqw),
    "S_scale_factor": 1.
}
background_config = None

model = SpecNeuralRepr.load_from_checkpoint(model_path).to(device)

steer = NeutronExperimentSteerer(
    model, particle_filter_config=particle_filter_config,
    mask_config=mask_config, experiment_config=experiment_config, background_config=background_config,
    likelihood_sample_ratio=0.25, tqdm_pbar=False, device='cuda')
# Out:
# obtained memmap mask name as: mask_h_-4.0_4.0_121_k_-4.0_4.0_121_l_-10.0_10.0_31_w_20.0_200.0_51.npy

# %%
plt.imshow(
    steer.experiment.Sqw.sum(dim=-1).sum(dim=-1).cpu().numpy())

# %%
mean_list = []
std_list = []
steer.reset()

true_params = spinw_data['params'][test_idx[idx_plot]].numpy()

print('true params: ', true_params)
# Out:
# true params:  [35.85150975  4.44331283]

# %%
with torch.no_grad():
    progress_bar = tqdm(range(50))
    for i in progress_bar:
        steer.step_steer(mode='unique_optimal')
        current_mean = steer.particle_filter.mean().detach().cpu()
        current_std = steer.particle_filter.std().detach().cpu()
        progress_bar.set_description(
            f'means: [{current_mean[0]:.3f}, {current_mean[1]:.3f}] '
            f' stds: [{current_std[0]:.3f}, {current_std[1]:.3f}]'
        )
        mean_list.append(current_mean)
        std_list.append(current_std)
# Out:
# means: [35.844, 4.364]  stds: [0.187, 0.131]: 100%|██████████| 50/50 [03:44<00:00,  4.49s/it]

# %%
steer.particle_filter.mean()
# Out:
# tensor([35.8437,  4.3637], dtype=torch.float64, grad_fn=<SumBackward1>)

# %%
measured_angles = np.vstack(steer.measured_angles_history).squeeze()
measured_angles[measured_angles > 180] -= 360
measured_angles
plt.plot(measured_angles)

# %%
from inxss.utils_visualization import visualize_utility

# %%
visualize_utility(steer.psi_mask.psi_grid, steer.utility_history[-1])
# Out:
# <PolarAxesSubplot:>

# %%
means = torch.vstack(mean_list).detach().numpy()[:]
std_dev = torch.vstack(std_list).detach().numpy()[:]

import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as patches

# Create some dummy data
scale_factor = 0.25
N = means.shape[0]
# means = np.cumsum(np.random.randn(N, 2), axis=0)
# stds = np.abs(np.random.randn(N, 2))

# Visualization
fig, ax = plt.subplots()

cmap = plt.get_cmap('Blues')
colors = [cmap(i) for i in np.linspace(0.2, 1, N)]

# Plot the evolution of the points with colormap
for i in range(N-1):
    ax.plot(means[i:i+2, 0], means[i:i+2, 1], '-o', color=colors[i], markersize=4)


# # Plot ovals for standard deviation
# for i in range(N):
#     ellipse = patches.Ellipse((means[i, 0], means[i, 1]),
#                               width=std_dev[i, 0]*scale_factor,  
#                               height=std_dev[i, 1]*scale_factor,
#                               edgecolor=None, facecolor=colors[i], alpha=0.2)  
#     ax.add_patch(ellipse)

ax.plot(means[-1,0], means[-1,1], 'o', label='Last Point', markersize=10, color='red')
ax.plot(true_params[0], true_params[1], '*', label='Ground Truth', markersize=10, color='red')

plt.scatter(steer.particle_filter.positions.data[0], steer.particle_filter.positions.data[1], c='gray')

ax.set_title('Evolution of 2D points with standard deviation')
ax.set_xlabel('$J$')
ax.set_ylabel('$J_{p}$')
# ax.set_xlim(20, 40)
# ax.set_ylim(-5, 5)
ax.legend()

plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(2,1)
axes[0].plot(torch.stack(steer.sig_bkg_factors_history).numpy()[:,0])
axes[1].plot(torch.stack(steer.sig_bkg_factors_history).numpy()[:,1])
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[33], line 2
#       1 fig, axes = plt.subplots(2,1)
# ----> 2 axes[0].plot(torch.stack(steer.sig_bkg_factors_history).numpy()[:,0])
#       3 axes[1].plot(torch.stack(steer.sig_bkg_factors_history).numpy()[:,1])
#
# RuntimeError: stack expects a non-empty TensorList
