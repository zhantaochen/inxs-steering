# %%
# %load_ext autoreload
# %autoreload 2
from inxss.utils_spectrum import calc_Sqw_from_Syy_Szz
from inxss.experiment import SimulatedExperiment

import torch
import numpy as np
from scipy.interpolate import RegularGridInterpolator

from inxss import SpectrumDataset, SpecNeuralRepr, Particle, PsiMask, OnlineVariance, linspace_2D_equidistant
from inxss.utils_visualization import arc_arrow, rad_arrow

import matplotlib.pyplot as plt

from tqdm import tqdm 

# device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
device = 'cpu'

torch.set_default_dtype(torch.float32)

# %%
from inxss.experiment import NeutronExperiment

# %%
data = torch.load('/pscratch/sd/z/zhantao/inxs_steering/experiment_data/summarized_neutron_data_260meV.pt')
print(data.keys())
# Out:
# dict_keys(['grid', 'S'])

# %% [markdown]
# ### setup experiment simulator

# %%
neutron_exp = NeutronExperiment(tuple([data['grid'][_grid] for _grid in ['h_grid', 'k_grid', 'l_grid']]), data['grid']['w_grid'], data['S'])

# %%
kpts, kpts_idx = linspace_2D_equidistant([[0,0],[0.5,0],[0.5,0.5],[0,0]], 100, return_indices=True)
kpts = torch.from_numpy(kpts)
wpts = neutron_exp.w_grid

x = torch.cat([
    kpts.unsqueeze(0).expand(wpts.shape[0], -1, -1),
    wpts.view(wpts.shape[0], -1).unsqueeze(1).expand(-1, kpts.shape[0], -1)
   ], dim=2)

# %%
s = neutron_exp.get_measurements_on_coords(x)

# %%
fig, ax = plt.subplots(1, 1)
ax.imshow(s, origin='lower', extent=[0, len(kpts), neutron_exp.w_grid.min(), neutron_exp.w_grid.max()])
ax.set_xticks(kpts_idx)
ax.set_xticklabels(['$\Gamma$', 'X', 'M','$\Gamma$']);
ax.set_ylabel('Energy $\omega$ (meV)')
fig.tight_layout()
fig.savefig('figures/temp_figures/neutron_experiment_data.svg', bbox_inches='tight')

# %% [markdown]
# ### setup neural network model

# %%
model = SpecNeuralRepr.load_from_checkpoint(
    '/pscratch/sd/z/zhantao/inxs_steering/lightning_logs/version_14896843/checkpoints/epoch=1165-step=55968.ckpt'
    ).to(device)

# %% [markdown]
# ### setup particle filter

# %%
prior_configs = {'types': ['uniform', 'uniform'], 'args': [{'low': 20, 'high': 40}, {'low': -5, 'high': 5}]}

particle = Particle(100, 2, prior_configs=prior_configs)
# particle.positions.data[:,0] = param_test
particle.grad_off()

# %% [markdown]
# ### setup mask mapping

# %%
raw_map_path = '/pscratch/sd/z/zhantao/inxs_steering/La2NiO4_bool'
memmap_mask_path='/pscratch/sd/z/zhantao/inxs_steering/mask_data'
grid_info = {
    _: [eval(f'neutron_exp.{_}').min().item(), eval(f'neutron_exp.{_}').max().item(), eval(f'neutron_exp.{_}').shape[0]] 
    for _ in ['h_grid', 'k_grid', 'l_grid', 'w_grid']}

psi_mask = PsiMask(raw_map_path, memmap_mask_path=memmap_mask_path,
                   grid_info=grid_info, device='cpu', preload=False, build_from_scratch_if_no_memmap=True,
                   global_mask=data['S']>0
                  )
psi_mask_full = PsiMask(raw_map_path, memmap_mask_path=memmap_mask_path,
                   grid_info=grid_info, device='cpu', preload=False, build_from_scratch_if_no_memmap=True,
                   global_mask=None
                  )
# Out:
# obtained memmap mask name as: mask_h_0.0_2.0_61_k_-2.0_2.0_121_l_-10.0_4.5_30_w_20.0_200.0_91.npy
# obtained memmap mask name as: mask_h_0.0_2.0_61_k_-2.0_2.0_121_l_-10.0_4.5_30_w_20.0_200.0_91.npy

# %%
first_angle = 10.
fig, ax = plt.subplots(1,2)
ax[0].imshow(
    (psi_mask.load_memmap_mask(first_angle).sum(axis=-1).sum(axis=-1)>1).T, 
    origin='lower', extent=[neutron_exp.h_grid.min(), neutron_exp.h_grid.max(), neutron_exp.k_grid.min(), neutron_exp.k_grid.max()])
ax[0].set_title(f"$\psi={first_angle}^{{\circ}}$")
ax[0].set_xlabel("$h$")
ax[0].set_ylabel("$k$")
ax[1].imshow((psi_mask.load_memmap_mask(first_angle+180).sum(axis=-1).sum(axis=-1)>1).T,
    origin='lower', extent=[neutron_exp.h_grid.min(), neutron_exp.h_grid.max(), neutron_exp.k_grid.min(), neutron_exp.k_grid.max()])
ax[1].set_title(f"$\psi={first_angle+180}^{{\circ}}$")
ax[1].set_xlabel("$h$")
ax[1].set_ylabel("$k$")
fig.tight_layout()

fig, ax = plt.subplots(1,2)
ax[0].imshow(
    (psi_mask_full.load_memmap_mask(first_angle).sum(axis=-1).sum(axis=-1)>1).T, 
    origin='lower', extent=[neutron_exp.h_grid.min(), neutron_exp.h_grid.max(), neutron_exp.k_grid.min(), neutron_exp.k_grid.max()])
ax[0].set_title(f"$\psi={first_angle}^{{\circ}}$")
ax[0].set_xlabel("$h$")
ax[0].set_ylabel("$k$")
ax[1].imshow((psi_mask_full.load_memmap_mask(first_angle+180).sum(axis=-1).sum(axis=-1)>1).T,
    origin='lower', extent=[neutron_exp.h_grid.min(), neutron_exp.h_grid.max(), neutron_exp.k_grid.min(), neutron_exp.k_grid.max()])
ax[1].set_title(f"$\psi={first_angle+180}^{{\circ}}$")
ax[1].set_xlabel("$h$")
ax[1].set_ylabel("$k$")
fig.tight_layout()

# fig.savefig('figures/temp_figures/mask_symmetry.svg', bbox_inches='tight')

# %% [markdown]
# ### Testing integrated steer module

# %%
from inxss.steer_neutron import NeutronExperimentSteerer

# %%
particle_filter_config = {
    "num_particles": 100,
    "dim_particles": 2,
    "prior_configs": {'types': ['uniform', 'uniform'], 'args': [{'low': 20, 'high': 40}, {'low': -5, 'high': 5}]}
}

grid_info = {
    _: [eval(f'neutron_exp.{_}').min().item(), eval(f'neutron_exp.{_}').max().item(), eval(f'neutron_exp.{_}').shape[0]] 
    for _ in ['h_grid', 'k_grid', 'l_grid', 'w_grid']}

mask_config = {
    "raw_mask_path": '/pscratch/sd/z/zhantao/inxs_steering/La2NiO4_bool',
    "memmap_mask_path": '/pscratch/sd/z/zhantao/inxs_steering/mask_data',
    "grid_info": grid_info,
    "preload": False,
    "build_from_scratch_if_no_memmap": False,
    "global_mask": data['S']>0
}

experiment_config = {
    "q_grid": tuple([data['grid'][_grid] for _grid in ['h_grid', 'k_grid', 'l_grid']]),
    "w_grid": data['grid']['w_grid'],
    "S_grid": data['S'],
    "S_scale_factor": 1.
}

model = SpecNeuralRepr.load_from_checkpoint(
    '/pscratch/sd/z/zhantao/inxs_steering/lightning_logs/version_14896843/checkpoints/epoch=1165-step=55968.ckpt'
    ).to(device)

steer = NeutronExperimentSteerer(
    model, particle_filter_config=particle_filter_config, 
    mask_config=mask_config, experiment_config=experiment_config, 
    likelihood_mask_threshold=0.5, tqdm_pbar=False, device='cuda')
# Out:
# obtained memmap mask name as: mask_h_0.0_2.0_61_k_-2.0_2.0_121_l_-10.0_4.5_30_w_20.0_200.0_91.npy

# %%
mean_list = []
std_list = []
steer.reset()

# %%
steer.likelihood_mask_threshold = 0.5
steer.particle_filter.positions.data[:,0] = torch.tensor([29, 1.7])

# %%
# print(data['params'][test_idx[idx_plot]])
with torch.no_grad():
    print(steer.particle_filter.mean().detach().cpu(), steer.particle_filter.std().detach().cpu()) 
    for i in tqdm(range(50)):
        steer.step_steer()
        print(steer.particle_filter.mean(), steer.particle_filter.std())
        mean_list.append(steer.particle_filter.mean().detach().cpu())
        std_list.append(steer.particle_filter.std().detach().cpu())
    
    # print(steer.particle_filter.positions[:10])
    # print(steer.particle_filter.weights[:10])
# Out:
# tensor([29.7856,  0.1986], dtype=torch.float64) tensor([5.4484, 2.9908], dtype=torch.float64)
#   2%|▏         | 1/50 [00:00<00:32,  1.51it/s]
# tensor([28.9531,  0.3005], dtype=torch.float64) tensor([5.7471, 3.0710], dtype=torch.float64)
#   4%|▍         | 2/50 [00:01<00:31,  1.51it/s]
# tensor([28.1269,  1.3227], dtype=torch.float64) tensor([6.4851, 3.1126], dtype=torch.float64)
#   6%|▌         | 3/50 [00:02<00:32,  1.47it/s]
# tensor([22.0174,  3.7373], dtype=torch.float64) tensor([5.4444, 2.6743], dtype=torch.float64)
#   8%|▊         | 4/50 [00:02<00:30,  1.51it/s]
# tensor([19.0733,  5.4578], dtype=torch.float64) tensor([1.8602, 1.2370], dtype=torch.float64)
#  10%|█         | 5/50 [00:03<00:29,  1.51it/s]
# tensor([18.5286,  5.8083], dtype=torch.float64) tensor([1.1850, 0.7224], dtype=torch.float64)
#  12%|█▏        | 6/50 [00:03<00:29,  1.52it/s]
# tensor([18.2780,  5.9199], dtype=torch.float64) tensor([1.0720, 0.6636], dtype=torch.float64)
#  14%|█▍        | 7/50 [00:04<00:29,  1.44it/s]
# tensor([18.1535,  5.9986], dtype=torch.float64) tensor([1.0232, 0.6371], dtype=torch.float64)
#  16%|█▌        | 8/50 [00:05<00:29,  1.44it/s]
# tensor([18.1440,  5.9698], dtype=torch.float64) tensor([0.9856, 0.6114], dtype=torch.float64)
#  18%|█▊        | 9/50 [00:06<00:27,  1.48it/s]
# tensor([17.9312,  6.0439], dtype=torch.float64) tensor([0.8866, 0.5836], dtype=torch.float64)
#  20%|██        | 10/50 [00:06<00:26,  1.51it/s]
# tensor([17.7767,  6.1371], dtype=torch.float64) tensor([0.8307, 0.5444], dtype=torch.float64)
#  22%|██▏       | 11/50 [00:07<00:25,  1.53it/s]
# tensor([17.6352,  6.2067], dtype=torch.float64) tensor([0.8146, 0.5249], dtype=torch.float64)
#  24%|██▍       | 12/50 [00:07<00:24,  1.54it/s]
# tensor([17.5411,  6.2745], dtype=torch.float64) tensor([0.9311, 0.5599], dtype=torch.float64)
#  26%|██▌       | 13/50 [00:08<00:23,  1.56it/s]
# tensor([17.2870,  6.3933], dtype=torch.float64) tensor([0.9066, 0.5581], dtype=torch.float64)
#  28%|██▊       | 14/50 [00:09<00:22,  1.57it/s]
# tensor([17.1160,  6.5003], dtype=torch.float64) tensor([0.9065, 0.5561], dtype=torch.float64)
#  30%|███       | 15/50 [00:10<00:24,  1.46it/s]
# tensor([16.9700,  6.5613], dtype=torch.float64) tensor([0.8784, 0.5598], dtype=torch.float64)
#  32%|███▏      | 16/50 [00:10<00:22,  1.50it/s]
# tensor([16.9529,  6.5627], dtype=torch.float64) tensor([0.8622, 0.5546], dtype=torch.float64)
#  34%|███▍      | 17/50 [00:11<00:21,  1.50it/s]
# tensor([16.8916,  6.6032], dtype=torch.float64) tensor([0.8550, 0.5483], dtype=torch.float64)
#  36%|███▌      | 18/50 [00:11<00:20,  1.53it/s]
# tensor([16.7671,  6.6578], dtype=torch.float64) tensor([0.8049, 0.5675], dtype=torch.float64)
#  38%|███▊      | 19/50 [00:12<00:20,  1.54it/s]
# tensor([16.6271,  6.8127], dtype=torch.float64) tensor([0.7770, 0.4948], dtype=torch.float64)
#  40%|████      | 20/50 [00:13<00:19,  1.54it/s]
# tensor([16.5933,  6.8822], dtype=torch.float64) tensor([0.7870, 0.4465], dtype=torch.float64)
#  42%|████▏     | 21/50 [00:13<00:18,  1.55it/s]
# tensor([16.4764,  6.9772], dtype=torch.float64) tensor([0.7416, 0.3950], dtype=torch.float64)
#  44%|████▍     | 22/50 [00:14<00:17,  1.56it/s]
# tensor([16.6365,  6.8612], dtype=torch.float64) tensor([0.8289, 0.4135], dtype=torch.float64)
#  46%|████▌     | 23/50 [00:15<00:18,  1.44it/s]
# tensor([16.5370,  6.9439], dtype=torch.float64) tensor([0.8073, 0.3876], dtype=torch.float64)
#  48%|████▊     | 24/50 [00:15<00:17,  1.49it/s]
# tensor([16.4825,  7.0044], dtype=torch.float64) tensor([0.7916, 0.3679], dtype=torch.float64)
#  50%|█████     | 25/50 [00:16<00:16,  1.50it/s]
# tensor([16.4765,  7.0436], dtype=torch.float64) tensor([0.7934, 0.3092], dtype=torch.float64)
#  52%|█████▏    | 26/50 [00:17<00:15,  1.53it/s]
# tensor([16.9217,  7.0118], dtype=torch.float64) tensor([0.9377, 0.3101], dtype=torch.float64)
#  54%|█████▍    | 27/50 [00:17<00:15,  1.53it/s]
# tensor([16.4827,  7.1502], dtype=torch.float64) tensor([0.7643, 0.2739], dtype=torch.float64)
#  56%|█████▌    | 28/50 [00:18<00:14,  1.55it/s]
# tensor([16.2877,  7.2057], dtype=torch.float64) tensor([0.5809, 0.2415], dtype=torch.float64)
#  58%|█████▊    | 29/50 [00:19<00:13,  1.55it/s]
# tensor([16.1921,  7.2344], dtype=torch.float64) tensor([0.4540, 0.2237], dtype=torch.float64)
#  60%|██████    | 30/50 [00:19<00:12,  1.57it/s]
# tensor([16.1236,  7.2388], dtype=torch.float64) tensor([0.3311, 0.2173], dtype=torch.float64)
#  62%|██████▏   | 31/50 [00:20<00:12,  1.49it/s]
# tensor([16.0828,  7.2190], dtype=torch.float64) tensor([0.2893, 0.2293], dtype=torch.float64)
#  64%|██████▍   | 32/50 [00:21<00:11,  1.53it/s]
# tensor([16.0970,  7.2611], dtype=torch.float64) tensor([0.2998, 0.2041], dtype=torch.float64)
#  66%|██████▌   | 33/50 [00:21<00:10,  1.56it/s]
# tensor([16.0422,  7.2790], dtype=torch.float64) tensor([0.2850, 0.2053], dtype=torch.float64)
#  68%|██████▊   | 34/50 [00:22<00:10,  1.57it/s]
# tensor([15.9945,  7.3195], dtype=torch.float64) tensor([0.1945, 0.1764], dtype=torch.float64)
#  70%|███████   | 35/50 [00:23<00:09,  1.56it/s]
# tensor([15.9848,  7.3105], dtype=torch.float64) tensor([0.2008, 0.1773], dtype=torch.float64)
#  72%|███████▏  | 36/50 [00:23<00:08,  1.58it/s]
# tensor([15.9533,  7.3251], dtype=torch.float64) tensor([0.2084, 0.1631], dtype=torch.float64)
#  74%|███████▍  | 37/50 [00:24<00:08,  1.59it/s]
# tensor([15.9319,  7.3666], dtype=torch.float64) tensor([0.1893, 0.1245], dtype=torch.float64)
#  76%|███████▌  | 38/50 [00:24<00:07,  1.59it/s]
# tensor([15.8883,  7.3895], dtype=torch.float64) tensor([0.1779, 0.0777], dtype=torch.float64)
#  78%|███████▊  | 39/50 [00:25<00:07,  1.46it/s]
# tensor([15.8675,  7.3965], dtype=torch.float64) tensor([0.1681, 0.0632], dtype=torch.float64)
#  80%|████████  | 40/50 [00:26<00:06,  1.50it/s]
# tensor([15.8525,  7.4049], dtype=torch.float64) tensor([0.1580, 0.0498], dtype=torch.float64)
#  82%|████████▏ | 41/50 [00:26<00:05,  1.53it/s]
# tensor([15.8335,  7.4095], dtype=torch.float64) tensor([0.1457, 0.0457], dtype=torch.float64)
#  84%|████████▍ | 42/50 [00:27<00:05,  1.52it/s]
# tensor([15.8162,  7.4141], dtype=torch.float64) tensor([0.1308, 0.0442], dtype=torch.float64)
#  86%|████████▌ | 43/50 [00:28<00:04,  1.53it/s]
# tensor([15.8019,  7.4211], dtype=torch.float64) tensor([0.1174, 0.0435], dtype=torch.float64)
#  88%|████████▊ | 44/50 [00:28<00:03,  1.54it/s]
# tensor([15.7756,  7.4227], dtype=torch.float64) tensor([0.1045, 0.0437], dtype=torch.float64)
#  90%|█████████ | 45/50 [00:29<00:03,  1.56it/s]
# tensor([15.7960,  7.4487], dtype=torch.float64) tensor([0.0884, 0.0416], dtype=torch.float64)
#  92%|█████████▏| 46/50 [00:30<00:02,  1.55it/s]
# tensor([15.7754,  7.4504], dtype=torch.float64) tensor([0.0778, 0.0403], dtype=torch.float64)
#  94%|█████████▍| 47/50 [00:30<00:02,  1.43it/s]
# tensor([15.7591,  7.4497], dtype=torch.float64) tensor([0.0723, 0.0396], dtype=torch.float64)
#  96%|█████████▌| 48/50 [00:31<00:01,  1.47it/s]
# tensor([15.7492,  7.4487], dtype=torch.float64) tensor([0.0703, 0.0396], dtype=torch.float64)
#  98%|█████████▊| 49/50 [00:32<00:00,  1.50it/s]
# tensor([15.7526,  7.4539], dtype=torch.float64) tensor([0.0699, 0.0392], dtype=torch.float64)
# 100%|██████████| 50/50 [00:32<00:00,  1.52it/s]
# tensor([15.7562,  7.4596], dtype=torch.float64) tensor([0.0673, 0.0363], dtype=torch.float64)

# %%
means = torch.vstack(mean_list).detach().numpy()[:]
std_dev = torch.vstack(std_list).detach().numpy()[:]

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as patches

# Create some dummy data
scale_factor = 0.25
N = means.shape[0]
# means = np.cumsum(np.random.randn(N, 2), axis=0)
# stds = np.abs(np.random.randn(N, 2))

# Visualization
fig, ax = plt.subplots()

cmap = plt.get_cmap('Blues')
colors = [cmap(i) for i in np.linspace(0.2, 1, N)]

# Plot the evolution of the points with colormap
for i in range(N-1):
    ax.plot(means[i:i+2, 0], means[i:i+2, 1], '-o', color=colors[i], markersize=4)


# # Plot ovals for standard deviation
# for i in range(N):
#     ellipse = patches.Ellipse((means[i, 0], means[i, 1]),
#                               width=std_dev[i, 0]*scale_factor,  
#                               height=std_dev[i, 1]*scale_factor,
#                               edgecolor=None, facecolor=colors[i], alpha=0.2)  
#     ax.add_patch(ellipse)

ax.plot(29.0, 1.68, '*', label='Ground Truth', markersize=10, color='red')

ax.set_title('Evolution of 2D points with standard deviation')
ax.set_xlabel('$J$')
ax.set_ylabel('$J_{p}$')
# ax.set_xlim(20, 40)
# ax.set_ylim(-5, 5)
ax.legend()

plt.tight_layout()
plt.show()

# %%
from inxss import linspace_2D_equidistant

# kpts, kpts_idx = linspace_2D_equidistant([[0,0],[0.5,0],[0.5,0.5],[0,0]], 100, return_indices=True)
# kpts = torch.from_numpy(kpts)

kpts, kpts_idx = linspace_2D_equidistant([[0,0],[1.5,0],[1.5,1.5],[0,0]], 100, return_indices=True)
kpts = torch.from_numpy(kpts)

# kpts = torch.from_numpy(linspace_2D_equidistant([[0,0],[0.5,0],[0.15,0.3],[0.5,0.5],[0,0]], 100))
# wpts = data['grid']['w_grid']

x = torch.zeros(wpts.shape[0], kpts.shape[0], 5)
x[...,:3] = torch.cat([
    kpts.unsqueeze(0).expand(wpts.shape[0], -1, -1),
    wpts.view(wpts.shape[0], -1).unsqueeze(1).expand(-1, kpts.shape[0], -1)
   ], dim=-1)
x[...,3:] = torch.tensor([29.0, 1.68])
S_pred = model(x.to(model.device)).reshape(wpts.shape[0], kpts.shape[0]).detach().cpu().numpy()
S_true = neutron_exp.get_measurements_on_coords(x[..., :3])

# S_true = calc_Sqw_from_Syy_Szz(_x, experiment.Syy_func, experiment.Szz_func)
print(S_true.mean() / S_pred.mean())
# Out:
# 17076.25991259819

# %%
fig, ax = plt.subplots(1, 2, figsize=(6, 5))
ax[0].imshow(S_true, origin='lower')
ax[0].set_title('True')
ax[1].imshow(S_pred, origin='lower')
ax[1].set_title('Predicted')
ax[0].set_xticks(kpts_idx)
ax[1].set_xticks(kpts_idx)
# fig.suptitle(rf'$J={param_test[0]:.2f}, \ J_{{p}}={param_test[1]:.2f}$')
fig.tight_layout()

# %%
steer.psi_mask.hklw_grid.shape
# Out:
# torch.Size([61, 121, 30, 91, 4])

# %%
x_input = torch.zeros(steer.psi_mask.hklw_grid.shape[:-1]+(5,))

x_input[...,:3] = steer.psi_mask.hklw_grid[...,[0,1,3]]
x_input[...,3:] = torch.tensor([29.0, 1.68])

# %%
steer.model.to('cuda');

# %%
s_pred = np.zeros((steer.psi_mask.hklw_grid.shape[0], steer.psi_mask.hklw_grid.shape[1], steer.psi_mask.hklw_grid.shape[3]))
k = 0
with torch.no_grad():
    for _x_input in tqdm(x_input.permute(2,0,1,3,4).reshape((-1, steer.psi_mask.hklw_grid.shape[0], steer.psi_mask.hklw_grid.shape[1], steer.psi_mask.hklw_grid.shape[3], 5,))):
        # print(_x_input.shape)
        _y_output = steer.model(_x_input.to('cuda')).detach().cpu().numpy()
        s_pred += _y_output
        k += 1
        # break
# Out:
# 100%|██████████| 30/30 [00:02<00:00, 14.60it/s]

# %%
fig, ax = plt.subplots(1, 1)
ax.imshow(
    s_pred[...,50].T, 
    extent=[steer.experiment.h_grid.min(), steer.experiment.h_grid.max(), steer.experiment.k_grid.min(), steer.experiment.k_grid.max()],
    origin='lower')
ax.set_xlabel('$h$')
ax.set_ylabel('$k$')
# Out:
# Text(0, 0.5, '$k$')

# %%
steer.experiment.Sqw.shape
# Out:
# torch.Size([61, 121, 30, 91])

# %%
fig, ax = plt.subplots(1, 1)
ax.imshow(
    steer.experiment.Sqw[...,50].sum(dim=-1).T, 
    extent=[steer.experiment.h_grid.min(), steer.experiment.h_grid.max(), steer.experiment.k_grid.min(), steer.experiment.k_grid.max()],
    origin='lower')
ax.set_xlabel('$h$')
ax.set_ylabel('$k$')
# Out:
# Text(0, 0.5, '$k$')

# %%
fig, ax = plt.subplots(1, 1)
ax.imshow(
    steer.experiment.Sqw.sum(dim=-1).sum(dim=-1).T, 
    extent=[steer.experiment.h_grid.min(), steer.experiment.h_grid.max(), steer.experiment.k_grid.min(), steer.experiment.k_grid.max()],
    origin='lower')
ax.set_xlabel('$h$')
ax.set_ylabel('$k$')
# Out:
# Text(0, 0.5, '$k$')
